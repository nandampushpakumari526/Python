# %%
#pip install pandas

# %%
import pandas as pd

# %%
a=[10,20,30,40,50]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=[4.5,6.7,8.9]
pd.Series(b)
# Out:
# 0    4.5
# 1    6.7
# 2    8.9
# dtype: float64

# %%
c=[5+5j,8+7j]
pd.Series(c)
# Out:
# 0    5.0+5.0j
# 1    8.0+7.0j
# dtype: complex128

# %%
d=[True,False]
pd.Series(d)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
e=["python","pandas"]
pd.Series(e)
# Out:
# 0    python
# 1    pandas
# dtype: str

# %%
d={"name":["pushpa","devi","pooja"],"marks":[60,70,80]}
pd.DataFrame(d)
# Out:
#      name  marks
# 0  pushpa     60
# 1    devi     70
# 2   pooja     80

# %%
#names,subject,marks,percentages
d={"name":["pushpa","devi","pooja","teja","prasanth"],"sujects":["maths","science","english","telugu","hindi"],"marks":[60,70,80,70,40],"percentage":[20,30,10,70,40]}
pd.DataFrame(d)
# Out:
#        name  sujects  marks  percentage
# 0    pushpa    maths     60          20
# 1      devi  science     70          30
# 2     pooja  english     80          10
# 3      teja   telugu     70          70
# 4  prasanth    hindi     40          40

# %%
data=pd.read_csv("names.csv")
data
# Out:
#        name      village
# 0    pushpa  mangalagiri
# 1      devi         vija
# 2   bharani    gudavalli
# 3      teja      krishna
# 4  prasanth     godavari

# %%
n=int(input())
d=[]
for i in range(4):
    name,salary,detm=input().split(",")
    d.append({"name":name,"salary":int(salary),"detm":detm})
df=pd.DataFrame(d)
print(df)
df=df.drop(0,axis=0)
result = df[df["salary"] >= n]
print(df)
for name in result["name"]:
    print(name)
# Out:
#  10000
#  pushpa,3000,cse
#  kumari,2000,eee
#  devi,10000,www
#  divya,50000,ccc
#      name  salary detm
# 0  pushpa    3000  cse
# 1  kumari    2000  eee
# 2    devi   10000  www
# 3   divya   50000  ccc
#      name  salary detm
# 1  kumari    2000  eee
# 2    devi   10000  www
# 3   divya   50000  ccc
# devi
# divya

# %%
data1=pd.read_csv("netflix.csv")
data1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data1.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %%
data1.shape
# Out:
# (8807, 12)

# %%
data1.info
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...
